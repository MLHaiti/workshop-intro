# %% [markdown]
# # PLAN

# %% [markdown]
# * The concept of Intelligence and memory
# * Importance of AI
# * How we should use AI in Haiti
# * Application of AI
#   * Health Care
#   * Transportation
#   * Speech recognition
#   * computer vision
#   * Autonomous Systems
#   * Space travel
#   * Etc.
# * Workshop
#   * Intro to python
#       * Data structure
#       *
#   * Intro to stats and ML
#       * Data type
#         * Categorical data
#         * Continuous data
#       * Plot data with Matplotlib
#       * Intro to pandas
#         * Data wranggling
#       * Data Transformation
#         * Normalization
#         * Standardization
#         * Etc.
#    * Go deeper in machine learning
#       * The process we follow to solve a Machine Learning problem
#       * How we choice features
#       * Analyse and visualize our data for selecting feature by importance
#       * How to choose your algorithm
#       * basic application of linear regression
#       * other example

# %% [markdown]
# # Karakteristik (Features)

# %% [markdown]
# Anpil nan done nap gen pou nou analize oubyen itilize gen yon bann karakteristik . Ann pran kòm examp yon moun .
# Nou ka jwenn omwen 4 karakterisktik nan yon moun que nan syans done yo rele yo **features** : Pwa, wotè , koulè po,sèks moun lan etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Nou ka pran yon kay tou : nap jwen sifas kay la , pri , twati kay la

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tip de varyab

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Nou ka gen plizyè tip de karakteristik tankou:
#     *   **Kategorik**
#     *   **Nimerik**
#
# Nap konsantre nou sou tip varyab kategorik : Nominal ak Òdinal , karakteristik  kontini(**continuous features**) yo.
#
# **Varyab nominal**: Se lè varyab la ka pran yon ansanm valè ki pa yon nomb e ki pa gen lòd . Ekzamp : koulè(ble , rouj, vèt , etc. )

# %% [markdown]
# # kouman nou ka reprezante done nou yo.
# Pwiske chak donne nou yo gen yonn ou yon pakèt karakterisktik . Pou moun ki fè matematik yo nou ka reprezante yo sou fòm vektè ou matris pi souvan. Nan langaj python yo konn itilize yon strikti done yo rele dataframe , Le plisouvan se ak yon library yo rele pandas yo itilize li . Typ done kòm matrix ak vektè prèske egzizte nan tout langaj programasyon . Nou ka chwazi oktav , R ou python paske langaj sa yo bay anpil opòtinite nan fason pou nou fè

# %% [markdown]
# Egzanp vektè ou list nan langaj python :

# %%
height = [1.75, .85, 1.60]
height
# Out:
# [1.75, 0.85, 1.6]

# %% [markdown]
# Ann eseye itilize senbòl adisyon nan yon list python.

# %%
height +[2,3,3]
# Out:
# [1.75, 0.85, 1.6, 2, 3, 3]

# %% [markdown]
# Lè nou fè sa nou wè se ajoute li ajoute lòt list la sou premye

# %%
two_time_height = [2*x for x in height]
two_time_height
# Out:
# [3.5, 1.7, 3.2]

# %%
t_height = height * 2
t_height
# Out:
# [1.75, 0.85, 1.6, 1.75, 0.85, 1.6]

# %% [markdown]
# ## numpy

# %% [markdown]
# Pou nou menm ki bezwen fè anpil matematik nap itilize yon bibliyotèk python kap ede nou fè kalkil nou yo pi byen

# %% [markdown]
# Numpy gen anpil type done matematik . Genyen vektè , matrix avèk tout operasyon ou ka fè sou yo .
# Ann bay detwa egzanp vektè ak **numpy** ak operasyon tou .

# %% [markdown]
# #### Operasyon sou vektè

# %%
import numpy as np

x_1 = np.array([1.4,2])
x_2 = np.array([5,9])
print("x_1= ", x_1)
print("x_2= ", x_2)

print("x_1 + x_2 = ", x_1 + x_2  )

print("2 * x_1 = ", 2*x_1)
# Out:
# x_1=  [ 1.4  2. ]
# x_2=  [5 9]
# x_1 + x_2 =  [  6.4  11. ]
# 2 * x_1 =  [ 2.8  4. ]

# %% [markdown]
# #### Operasyon sou matris

# %%
X_1 = np.matrix([[1,2],[2,3]])
print( "Matrix X_1 = " ,X_1)

X_2 = np.matrix([[2,4], [3,5]])
print( "Matrix X_2 =" ,X_1)

print( "Matrix X_1 + X_2 =" ,X_1+X_2)

print( "X_1 * X_2 =", X_1 * X_2)
# Out:
# Matrix X_1 =  [[1 2]
#  [2 3]]
# Matrix X_2 = [[1 2]
#  [2 3]]
# Matrix X_1 + X_2 = [[3 6]
#  [5 8]]
# X_1 * X_2 = [[ 8 14]
#  [13 23]]

# %% [markdown]
# ## Ann koumanse ak regresyon lineyè

# %% [markdown]
# Kisa regresyon lineyè a ye?
# Regresyon linyè:
#     Se yon mwayen yo itilize pou predi done kontini pa egzan laj , pri kay , etc.

# %% [markdown]
# Ann enpòte yon ansanm de done ki gen pri kay , sifas kay , kantite chanm yo genyen

# %%
houses = np.loadtxt("houses/housesandprices.txt",dtype=np.float64,delimiter=",")

houses[:5,::]
# Out:
# array([[  2.10400000e+03,   3.00000000e+00,   3.99900000e+05],
#        [  1.60000000e+03,   3.00000000e+00,   3.29900000e+05],
#        [  2.40000000e+03,   3.00000000e+00,   3.69000000e+05],
#        [  1.41600000e+03,   2.00000000e+00,   2.32000000e+05],
#        [  3.00000000e+03,   4.00000000e+00,   5.39900000e+05]])

# %%
X = houses[::,:2]
Y = houses[::,-1:]

# %% [markdown]
# Ann afiche done sa yo sou yon tablo avec matplotlib

# %%
plt.figure(figsize = (15,4),dpi=100)
plt.subplot(121)
plt.scatter(X[::,0:1], Y )
plt.xlabel("Sifas(pye kare)")
plt.ylabel("Pri kay yo")

plt.subplot(122)
plt.scatter(X[::,1:2], Y)
plt.show()

# %% [markdown]
# #### Pwosesis pou nou rezoud pwoblèm lan e kisa pwoblèm lan ye
#
# Avèk done sa yo nou genyen an nou ta renmen kapab reponn kesyon sa : **si mwen gen yon kay ki gen x_1 pye kare ak x_2 chanm konbyen kòb lap koute?**

# %% [markdown]
# Aprè lèn fin desine done nou yo sou ekran nap gen pou nou chwazi yon pakèt done la dan yo nap rele ( done entrenman ,)
# **training set** nan lang angle,
# Epi lòt pati a nap rele li done(ansanm) tès yo (training set)

# %% [markdown]
# Etan done nou pa gen fonksyon ki kapab ban nou yon bon relasyon, nap fè done yo bann yonn . Se sa ki travay **Aprantisaj sipèvize** a menm . Banm montre yon imaj pou nou ka byen konpran
# ![image.png](attachment:image.png)

# %% [markdown]
# Nan ka pa nou an , nou bezwen yon fonksyon kap pèmèt nou jwenn pri kay yo menm si li pa fè pati de done nou genyen yo .
# Nan regresyon lineyè fonksyon nap chèche a dwe ekri konsa :
#      **y(pri kay la) = alpha_1 * x_1(sifas) + alpha_2 * x_2(kantite chanm) + beta(byè)**

# %% [markdown]
# #### Ann eseye enplemante algorit regression lineyè  a
#
# ##### Gradient descent
#
# Premye bagay nou ka eseye enplemante se **gradient descent**
#
# Nan tewori nou te fè sou tablo yo , nou te wè kisa **gradient descent** lan ye . Ann fè algorit python kap pèmèt nou jwenn **grandyan** nou yo.

# %%
def cost(X_bias,Y,Theta):
    m,n = X.shape
    hypothesis = X_bias.dot(Theta.transpose())
    return (1/(2.0*m))*(np.square(hypothesis - Y))


def gradient_descent(X_bias,Y,Theta, iterations, alpha):
    i = 1
    arr_cost = np.array([])
    while(i<iterations):
        hypothesis = X_bias.dot(Theta.transpose())
        temp0 = Theta[0,0] - alpha*(1.0/m)*((hypothesis-Y)*(X_bias[::,0:1])).sum(axis=0)
        temp1 = Theta[0,1] - alpha*(1.0/m)*((hypothesis-Y)*(X_bias[::,1:2])).sum(axis=0)
        temp2 = Theta[0,2] - alpha*(1.0/m)*((hypothesis-Y)*(X_bias[::,-1:])).sum(axis=0)
        Theta[0,0] = temp0
        Theta[0,1] = temp1
        Theta[0,2] = temp2
        arr_cost = np.append(arr_cost,cost(X_bias,Y,Theta))
        i = i + 1
    #plt.plot(np.linspace(1,iterations,endpoint=True),arr_cost)
    plt.title("Iteration vs Cost graph ")
    plt.xlabel("Number of iteration")
    plt.ylabel("Cost of Theta")
    plt.show()
    return Theta

# %% [markdown]
# Ann mete byè nan done yo

# %%
m, n = X.shape
X_bias = np.ones((m,n+1))
X_bias[::,1:] = X

print("X_bias = \n ",X_bias[0:5,:])
print("Y =\n", Y[0:5,::])
# Out:
# X_bias =
#   [[  1.00000000e+00   2.10400000e+03   3.00000000e+00]
#  [  1.00000000e+00   1.60000000e+03   3.00000000e+00]
#  [  1.00000000e+00   2.40000000e+03   3.00000000e+00]
#  [  1.00000000e+00   1.41600000e+03   2.00000000e+00]
#  [  1.00000000e+00   3.00000000e+03   4.00000000e+00]]
# Y =
#  [[ 399900.]
#  [ 329900.]
#  [ 369000.]
#  [ 232000.]
#  [ 539900.]]

# %% [markdown]
# #### Nap mete done yo sou menm echèl (Feature scaling)

# %%
mean_size = np.mean(X_bias[::,1:2])
mean_bedroom = np.mean(X_bias[::,2:])
size_std = np.std(X_bias[::,1:2])
bedroom_std = np.std(X_bias[::,2:])
X_bias[::,1:2] = (X_bias[::,1:2] - mean_size)/ (size_std) 
X_bias[::,2:] = (X_bias[::,2:] - mean_bedroom)/ (bedroom_std)
X_bias[0:5,::]
# Out:
# array([[ 1.        ,  0.13141542, -0.22609337],
#        [ 1.        , -0.5096407 , -0.22609337],
#        [ 1.        ,  0.5079087 , -0.22609337],
#        [ 1.        , -0.74367706, -1.5543919 ],
#        [ 1.        ,  1.27107075,  1.10220517]])

# %%
Theta = np.random.rand(1,3)
alpha = 0.3
iterations = 100
Theta = gradient_descent(X_bias,Y,Theta,iterations,alpha)
print (Theta)
# Out:
# [[ 340412.65957447  109447.74899172   -6578.30737624]]

# %%
X_predict = np.array([1.0,1650.0,3]) 
#feature scaling the data first
X_predict[1] = (X_predict[1] - mean_size)/ (size_std) 
X_predict[2] = (X_predict[2]- mean_bedroom)/ (bedroom_std)
hypothesis = X_predict.dot(Theta.transpose())
print ("Cost of house with 1650 sq ft and 3 bedroom is ",hypothesis)
# Out:
# Cost of house with 1650 sq ft and 3 bedroom is  [  1.80909464e+08]

# %% [markdown]
# ### Titanic problem

# %% [markdown]
# Nou pral itilize yon bibliyotèk ki pwisan anpil pou nou fait analiz done.
#
# #### Pandas

# %% [markdown]
# #### Ann pran done yo nan fichye yo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
train_data = pd.read_csv("data/titanic/train.csv",index_col='PassengerId')
test_data = pd.read_csv("data/titanic/test.csv",index_col='PassengerId')

# %% [markdown]
# **Konbyen done ki genyen nan train_data ?**

# %%
train_data.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
test_data.count()
# Out:
# Pclass      418
# Name        418
# Sex         418
# Age         332
# SibSp       418
# Parch       418
# Ticket      418
# Fare        417
# Cabin        91
# Embarked    418
# dtype: int64

# %%
train_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Mwen renmen gade infomasyon sou done yo. Mwen itilize propriyete info a

# %%
train_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **Ann eseye wè ki laj majorite moun sa yo te genyen**

# %%
train_data["Age"].plot.hist()

# %% [markdown]
# Nou kapab analize moun ki mouri yo pou nou wè konbyen. Nap itilize yon bibliyotek yo rele **seaborn** pou nou fè sa .

# %%
import seaborn as sns

sns.countplot(x="Survived", data=train_data)

# %% [markdown]
# **Nou ka gade konbyen ki sove pa rapo a seks yo .**

# %%
sns.countplot(x="Survived", hue="Sex", data=train_data)

# %% [markdown]
# Nou kapab wè eta done nou yo tou poun gade karakteristik ki gen anpil null ladan

# %%
sns.heatmap(train_data.isnull())

# %%
train_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %% [markdown]
# #### Ann eseye gade si kote  moun lan te anbake a ka fait li sove

# %%
train_data.groupby('Embarked')[['Survived']].mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# ### Ann gade yon seri de done si yo gen corelasyon antre yo menm

# %%
train_data.corr()['Survived'].sort_values(ascending=False)
# Out:
# Survived    1.000000
# Fare        0.257307
# Parch       0.081629
# SibSp      -0.035322
# Age        -0.077221
# Pclass     -0.338481
# Name: Survived, dtype: float64

# %% [markdown]
# Se komsi sex moun lan pa parèt nan korelasyon an . Ann fè yon lot analyse sou sex yo :

# %%
train_data.groupby('Sex').count()
# Out:
#         Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Sex
# female       314     314   314  261    314    314     314   314     97
# male         577     577   577  453    577    577     577   577    107
#
#         Embarked
# Sex
# female       312
# male         577

# %% [markdown]
# Nou kapab wè gason yo plis nan done nou yo .
#
# Nou pral nan yon lòt pati ki se transfòmasyon done

# %% [markdown]
# #### Data transformation
#
# Nap bezwen konvèti donè categorik yo an done nimerik.
# Fok nou ta fè sa nan data_train epi data_test yo tou .
#
# Ann komanse pa konkatene done sa yo ansanm
#
# nap retire etiket(label) yo nan train_data yo

# %%
y_train = train_data["Survived"]

train_data = train_data.drop("Survived", axis=1)

# mwen ap mete test ak train ansanm
train_data["Training_set"] = True
test_data["Training_set"] = False

df_all = pd.concat([train_data, test_data])
df_all.isnull().sum()
# Out:
# Pclass             0
# Name               0
# Sex                0
# Age              263
# SibSp              0
# Parch              0
# Ticket             0
# Fare               1
# Cabin           1014
# Embarked           2
# Training_set       0
# dtype: int64

# %%
df_all.head()
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
#             Embarked  Training_set
# PassengerId
# ...

# %%
df_all[df_all.Embarked.isnull()]
# Out:
#              Pclass                                       Name     Sex   Age  \
# PassengerId
# 62                1                        Icard, Miss. Amelie  female  38.0
# 830               1  Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0
#
#              SibSp  Parch  Ticket  Fare Cabin Embarked  Training_set
# PassengerId
# 62               0      0  113572  80.0   B28      NaN          True
# 830              0      0  113572  80.0   B28      NaN          True

# %% [markdown]
# Ann bay de moun sa yo que nou pa wè kote yo embarke valè ki plis repete  a kòm valê pa defo

# %%
df_all['Embarked']= df_all['Embarked'].fillna(value=df_all['Embarked'].value_counts().index[0])

# %%
df_all.loc[[62, 830]]
# Out:
#              Pclass                                       Name     Sex   Age  \
# PassengerId
# 62                1                        Icard, Miss. Amelie  female  38.0
# 830               1  Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0
#
#              SibSp  Parch  Ticket  Fare Cabin Embarked  Training_set
# PassengerId
# 62               0      0  113572  80.0   B28        S          True
# 830              0      0  113572  80.0   B28        S          True

# %% [markdown]
# **Ann konvèti varyab kategorik yo an variab binè**
# Nou gen **Embarked , Sex** apres nap fait pou lot yo

# %%
df_all = df_all.join(pd.get_dummies(df_all[['Sex', 'Embarked']]))
df_all.drop(['Sex','Embarked'], axis=1, inplace=True)

# %%
df_all.tail()
# Out:
#              Pclass                          Name   Age  SibSp  Parch  \
# PassengerId
# 1305              3            Spector, Mr. Woolf   NaN      0      0
# 1306              1  Oliva y Ocana, Dona. Fermina  39.0      0      0
# 1307              3  Saether, Mr. Simon Sivertsen  38.5      0      0
# 1308              3           Ware, Mr. Frederick   NaN      0      0
# 1309              3      Peter, Master. Michael J   NaN      1      1
#
#                          Ticket      Fare Cabin  Training_set  Sex_female  \
# PassengerId
# 1305                  A.5. 3236    8.0500   NaN         False           0
# 1306                   PC 17758  108.9000  C105         False           1
# 1307         SOTON/O.Q. 3101262    7.2500   NaN         False           0
# 1308                     359309    8.0500   NaN         False           0
# 1309                       2668   22.3583   NaN         False           0
#
#              Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# ...

# %% [markdown]
# Kounye a nou ta dwe encode **Cabin** , pou nou fè sa ann fè yon analiz .
#     * Nap eseye jwenn tout **Cabin** ki gen lèt *F* ladanl avec **pandas**

# %%
df_all['Cabin'][df_all.Cabin.notnull() & df_all.Cabin.str.contains('F') ]
# Out:
# PassengerId
# 67        F33
# 76      F G73
# 129     F E69
# 149        F2
# 184        F4
# 194        F2
# 341        F2
# 346       F33
# 517       F33
# 619        F4
# 700     F G63
# 716     F G73
# 777       F38
# 949     F G63
# 1001        F
# 1070       F4
# 1114      F33
# 1180    F E46
# 1213    F E57
# 1214       F2
# 1218       F4
# Name: Cabin, dtype: object

# %% [markdown]
# Nou jwenn anpil ki gen lèt F et ki komanse par F .
#
# **Kunye a ann pran premye lèt nan  tout Cabin ki gen valè  yo nou mete yo nan yon varyab yo rele Blok_list **

# %%
print(list(map(lambda x: x[0], df_all.Cabin.dropna().tolist())))
blok_list = list(map(lambda x: x[0], df_all.Cabin.dropna().tolist()))
# Out:
# ['C', 'C', 'E', 'G', 'C', 'D', 'A', 'C', 'B', 'D', 'B', 'C', 'B', 'C', 'F', 'F', 'C', 'E', 'A', 'D', 'D', 'C', 'B', 'E', 'D', 'F', 'D', 'C', 'B', 'F', 'C', 'E', 'B', 'A', 'C', 'F', 'A', 'F', 'B', 'B', 'G', 'A', 'D', 'D', 'C', 'C', 'C', 'D', 'G', 'C', 'B', 'E', 'B', 'C', 'C', 'C', 'D', 'A', 'B', 'D', 'C', 'C', 'B', 'E', 'C', 'C', 'E', 'C', 'B', 'C', 'E', 'C', 'D', 'B', 'C', 'C', 'C', 'E', 'T', 'F', 'C', 'F', 'C', 'E', 'D', 'B', 'E', 'C', 'B', 'D', 'G', 'C', 'E', 'C', 'E', 'B', 'C', 'A', 'C', 'C', 'C', 'E', 'D', 'E', 'E', 'D', 'A', 'B', 'C', 'B', 'C', 'D', 'C', 'B', 'C', 'E', 'D', 'F', 'B', 'B', 'C', 'B', 'B', 'B', 'C', 'C', 'A', 'E', 'C', 'E', 'E', 'C', 'A', 'E', 'B', 'D', 'A', 'C', 'F', 'D', 'D', 'D', 'A', 'B', 'B', 'D', 'A', 'D', 'E', 'C', 'B', 'B', 'D', 'B', 'B', 'C', 'F', 'C', 'E', 'E', 'C', 'C', 'C', 'F', 'C', 'E', 'E', 'B', 'B', 'D', 'C', 'B', 'B', 'D', 'E', 'B', 'B', 'D', 'E', 'F', 'B', 'B', 'D', 'B', 'D', 'B', 'A', 'E', 'B', 'B', 'E', 'B', 'E', 'C', 'C', 'D', 'E', 'D', 'A', 'D
# ...

# %% [markdown]
# Nou pral kreye karakteristik yo rele **Blok**
#
# **Blok**  ap gen valè ki koumanse kabin lan. Si Cabin lan pa gen valè nap mete  'X'

# %%
crit = df_all['Cabin'].isnull()
df_all['Blok'] = df_all['Cabin'].astype(str).str[0].where(~crit, other='X')
df_all.tail()
# Out:
#              Pclass                          Name   Age  SibSp  Parch  \
# PassengerId
# 1305              3            Spector, Mr. Woolf   NaN      0      0
# 1306              1  Oliva y Ocana, Dona. Fermina  39.0      0      0
# 1307              3  Saether, Mr. Simon Sivertsen  38.5      0      0
# 1308              3           Ware, Mr. Frederick   NaN      0      0
# 1309              3      Peter, Master. Michael J   NaN      1      1
#
#                          Ticket      Fare Cabin  Training_set  Sex_female  \
# PassengerId
# 1305                  A.5. 3236    8.0500   NaN         False           0
# 1306                   PC 17758  108.9000  C105         False           1
# 1307         SOTON/O.Q. 3101262    7.2500   NaN         False           0
# 1308                     359309    8.0500   NaN         False           0
# 1309                       2668   22.3583   NaN         False           0
#
#              Sex_male  Embarked_C  Embarked_Q  Embarked_S Blok
# ...

# %% [markdown]
# ### Kunye a nou ka retirer Cabin kom karakterisk epi nou , Bineariser Deck ki se yon variable nominal .

# %%
df_all = df_all.join(pd.get_dummies(df_all[['Blok']]))
df_all.drop("Blok", axis=1, inplace=True)
df_all.tail()
# Out:
#              Pclass                          Name   Age  SibSp  Parch  \
# PassengerId
# 1305              3            Spector, Mr. Woolf   NaN      0      0
# 1306              1  Oliva y Ocana, Dona. Fermina  39.0      0      0
# 1307              3  Saether, Mr. Simon Sivertsen  38.5      0      0
# 1308              3           Ware, Mr. Frederick   NaN      0      0
# 1309              3      Peter, Master. Michael J   NaN      1      1
#
#                          Ticket      Fare Cabin  Training_set  Sex_female  \
# PassengerId
# 1305                  A.5. 3236    8.0500   NaN         False           0
# 1306                   PC 17758  108.9000  C105         False           1
# 1307         SOTON/O.Q. 3101262    7.2500   NaN         False           0
# 1308                     359309    8.0500   NaN         False           0
# 1309                       2668   22.3583   NaN         False           0
#
# ...

# %% [markdown]
# Ann jwenn yon fason pou nou rempli valè ki manke yo pou **Features**: Age , Fare

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(strategy='median')
imputer.fit(df_all[['Age', 'Fare']])
df_all[['Age', 'Fare']] = imputer.transform(df_all[['Age', 'Fare']])

# %%
df_all[['Age', 'Fare']].tail()
# Out:
#               Age      Fare
# PassengerId
# 1305         28.0    8.0500
# 1306         39.0  108.9000
# 1307         38.5    7.2500
# 1308         28.0    8.0500
# 1309         28.0   22.3583

# %% [markdown]
# Ann retire train_data ak test_data nan df_all .

# %%
train_data = df_all[df_all['Training_set'] == True]
train_data.drop('Training_set', axis=1)
test_data = df_all[df_all['Training_set'] == False]
test_data.drop('Training_set', axis=1)
train_data.shape, test_data.shape
# Out:
# ((891, 23), (418, 23))

# %%
train_data.describe(include='number')
# Out:
#            Pclass         Age       SibSp       Parch        Fare  Sex_female  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.361582    0.523008    0.381594   32.204208    0.352413
# std      0.836071   13.019697    1.102743    0.806057   49.693429    0.477990
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#          Sex_male  Embarked_C  Embarked_Q  Embarked_S      Blok_A      Blok_B  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.647587    0.188552    0.086420    0.725028    0.016835    0.052750
# ...

# %%
train_data.describe(include='O')
# Out:
#                           Name Ticket    Cabin
# count                      891    891      204
# unique                     891    681      147
# top     Lievens, Mr. Rene Aime   1601  B96 B98
# freq                         1      7        4

# %%
df_tmp = train_data.select_dtypes('number').join(y_train)
df_tmp.corr()['Survived'].sort_values(ascending=False)
# Out:
# Survived      1.000000
# Sex_female    0.543351
# Fare          0.257307
# Blok_B        0.175095
# Embarked_C    0.168240
# Blok_D        0.150716
# Blok_E        0.145321
# Blok_C        0.114652
# Parch         0.081629
# Blok_F        0.057935
# Blok_A        0.022287
# Blok_G        0.016040
# Embarked_Q    0.003650
# Blok_T       -0.026456
# SibSp        -0.035322
# Age          -0.064910
# Embarked_S   -0.149683
# Blok_X       -0.316912
# Pclass       -0.338481
# Sex_male     -0.543351
# Name: Survived, dtype: float64

# %%
X_train = train_data.select_dtypes('number')
X_Test = test_data.select_dtypes('number')
y_train.shape, X_train.shape, X_Test.shape
# Out:
# ((891,), (891, 19), (418, 19))

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_Pred = logreg.predict(X_Test)
acc_log = round(logreg.score(X_train, y_train) * 100, 2)
acc_log
# Out:
# 80.810000000000002

# %%
df_lr_coeff = pd.DataFrame(X_train.columns)
df_lr_coeff.columns = ['Feature']
df_lr_coeff['Correlation'] = pd.Series(logreg.coef_[0])
df_lr_coeff.sort_values(by='Correlation', ascending=False)
# Out:
#        Feature  Correlation
# 5   Sex_female     2.136587
# 14      Blok_E     1.046247
# 7   Embarked_C     0.725510
# 15      Blok_F     0.684117
# 13      Blok_D     0.668974
# 8   Embarked_Q     0.568491
# 9   Embarked_S     0.322139
# 11      Blok_B     0.251668
# 10      Blok_A     0.206647
# 4         Fare     0.003287
# 1          Age    -0.035907
# 3        Parch    -0.095330
# 12      Blok_C    -0.205018
# 17      Blok_T    -0.235872
# 18      Blok_X    -0.312042
# 2        SibSp    -0.312325
# 16      Blok_G    -0.488581
# 6     Sex_male    -0.520447
# 0       Pclass    -0.768585

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron, SGDClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import  AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier

# %%
scoring = []
models= [Perceptron(), SGDClassifier(), GaussianNB(), LogisticRegression(), \
         KNeighborsClassifier(n_neighbors=3), LinearSVC(), SVC(), DecisionTreeClassifier(),\
         RandomForestClassifier(n_estimators=100), AdaBoostClassifier(n_estimators=100),\
         GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=4)]
for model in models:
    model.fit(X_train, y_train)
    y_Pred = model.predict(X_Test)
    scoring.append(model.score(X_train, y_train) * 100)
    
df_scores = pd.DataFrame({"Model": models, "Score": scoring})
df_scores.sort_values(by='Score', ascending=False)
# Out:
# /Users/thecassion/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /Users/thecassion/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# ...

# %%
gender_submission = pd.read_csv("data/titanic/gender_submission.csv")
gender_submission =
# Out:
#   File "<ipython-input-101-50cdcafdb5e1>", line 2
#     gender_submission =
#                         ^
# SyntaxError: invalid syntax
